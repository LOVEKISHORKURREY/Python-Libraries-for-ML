# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x=[1, 2, 3, 4, 5]
y=[1, 4, 9, 16, 25]

# %%
plt.plot(x, y)

# %%
z=[1, 5, 6, 9, 13]

# %%
plt.plot(z)
plt.plot(y)
plt.legend(labels=['A','B','C'], loc='upper right')
plt.xticks(ticks=[0, 1, 2, 3], labels=['A', 'B', 'C', 'D'])
# Out:
# ([<matplotlib.axis.XTick at 0x1ddf08d2fd0>,
# ...
#  [Text(0, 0, 'A'), Text(0, 0, 'B'), Text(0, 0, 'C'), Text(0, 0, 'D')])

# %%
plt.plot([1,2,3,4,5],[1,2,3,2,1],'g')
plt.xticks(ticks=[1,2,3,4,5],labels=['a','b','c','d','e'])
# Out:
# ([<matplotlib.axis.XTick at 0x1ddf096aca0>,
# ...
#  [Text(0, 0, 'a'),
#   Text(0, 0, 'b'),
#   Text(0, 0, 'c'),
#   Text(0, 0, 'd'),
#   Text(0, 0, 'e')])

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(6,6),sharey=True)
ax[0].plot([1,2,3,4],[4,3,2,1],'r*')
ax[1].plot([1,2,3,4,5],[1,2,1,3,5],'ro')

# %%
df=pd.read_csv(r'C:\Users\lovek\OneDrive\Desktop\churn_prediction.csv')

# %%
df
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 0                1     3135   66    Male         0.0  self_employed   187.0
# 1                2      310   35    Male         0.0  self_employed     NaN
# 2                4     2356   31    Male         0.0       salaried   146.0
# 3                5      478   90     NaN         NaN  self_employed  1020.0
# 4                6     2531   42    Male         2.0  self_employed  1494.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 28377        30297     1845   10  Female         0.0        student  1020.0
# 28378        30298     4919   34  Female         0.0  self_employed  1046.0
# 28379        30299      297   47    Male         0.0       salaried  1096.0
# 28380        30300     2585   50    Male         3.0  self_employed  1219.0
# 28381        30301     2349   18    Male         0.0        student  1232.0
#
# ...

# %%
x=df['age'].head(10)
y=df['vintage'].head(10)
plt.plot(x,y)

# %%
x=df['age']
y=df['occupation']
z=df['customer_id']
plt.bar(y,z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-29130d65dd9d> in <module>
#       2 y=df['occupation']
#       3 z=df['customer_id']
# ----> 4 plt.bar(y,z)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
x=df['occupation']
x
# Out:
# 0        self_employed
# 1        self_employed
# 2             salaried
# 3        self_employed
# 4        self_employed
#              ...
# 28377          student
# 28378    self_employed
# 28379         salaried
# 28380    self_employed
# 28381          student
# Name: occupation, Length: 28382, dtype: object

# %%
y=[1, 2,3,4,5,6,7,8,9]

# %%
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-63f59a9a48ad> in <module>
# ----> 1 plt.bar(x,y)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
x=pd.pivot_table(df,index=['occupation'])

# %%
y=df['age']

# %%
plt.bar(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-4b360245d724> in <module>
# ----> 1 plt.bar(x,y)
#       2
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2405         x, height, width=0.8, bottom=None, *, align='center',
#    2406         data=None, **kwargs):
# -> 2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
#    2409         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
plt.hist(df['age'].head(1000),bins=30,color='pink')
# Out:
# (array([ 4.,  6.,  7.,  6.,  5.,  9., 19., 35., 49., 37., 61., 61., 68.,
#         68., 71., 65., 59., 55., 25., 39., 41., 33., 36., 42., 23., 16.,
#         14.,  8.,  2., 36.]),
#  array([ 3. ,  5.9,  8.8, 11.7, 14.6, 17.5, 20.4, 23.3, 26.2, 29.1, 32. ,
#         34.9, 37.8, 40.7, 43.6, 46.5, 49.4, 52.3, 55.2, 58.1, 61. , 63.9,
#         66.8, 69.7, 72.6, 75.5, 78.4, 81.3, 84.2, 87.1, 90. ]),
#  <a list of 30 Patch objects>)

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
m=dict(markerfacecolor='r',marker='D')
plt.boxplot(df[['age']].values, labels=['age'],flierprops=m)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dda05c7430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dda05c7af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dda05c70d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dda05cf1f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dda05cf4f0>],
#  'means': []}

# %%
df[['age']].head()
# Out:
#    age
# 0   66
# 1   35
# 2   31
# 3   90
# 4   42

# %%
x=df[['age']]
plt.boxplot(x.values,labels=['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dda06039d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dda060d0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dda0603670>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dda060d790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dda060da90>],
#  'means': []}

# %%
df[['occupation']].head(12)
# Out:
#        occupation
# 0   self_employed
# 1   self_employed
# 2        salaried
# 3   self_employed
# 4   self_employed
# 5   self_employed
# 6         retired
# 7   self_employed
# 8        salaried
# 9   self_employed
# 10        retired
# 11       salaried

# %%
plt.violinplot(df[['age']].values)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1ddbe225790>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1ddbe2255e0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1ddbe225640>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1ddbe225be0>}

# %%
df[['age','occupation']].head(15)
# Out:
#     age     occupation
# 0    66  self_employed
# 1    35  self_employed
# 2    31       salaried
# 3    90  self_employed
# 4    42  self_employed
# 5    42  self_employed
# 6    72        retired
# 7    46  self_employed
# 8    31       salaried
# 9    40  self_employed
# 10   68        retired
# 11   32       salaried
# 12   73        retired
# 13   50       salaried
# 14   48  self_employed

# %%
plt.scatter(df['age'][:20],df['customer_id'][:20])

# %%
plt.scatter(df['age'][:10],df['customer_id'][:10],s=df['vintage'][:10]*0.1)

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...
