# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\lovek\OneDrive\Desktop\churn_prediction.csv")

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df[["customer_id", "age", "gender", "churn"]]
# Out:
#        customer_id  age  gender  churn
# 0                1   66    Male      0
# 1                2   35    Male      0
# 2                4   31    Male      0
# 3                5   90     NaN      1
# 4                6   42    Male      1
# ...            ...  ...     ...    ...
# 28377        30297   10  Female      0
# 28378        30298   34  Female      0
# 28379        30299   47    Male      1
# 28380        30300   50    Male      0
# 28381        30301   18    Male      1
#
# [28382 rows x 4 columns]

# %%
df["age"].head()
# Out:
# 0    66
# 1    35
# 2    31
# 3    90
# 4    42
# Name: age, dtype: int64

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df.tail()
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 28377        30297     1845   10  Female         0.0        student  1020.0
# 28378        30298     4919   34  Female         0.0  self_employed  1046.0
# 28379        30299      297   47    Male         0.0       salaried  1096.0
# 28380        30300     2585   50    Male         3.0  self_employed  1219.0
# 28381        30301     2349   18    Male         0.0        student  1232.0
#
#        customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 28377                     2         1207                         70.0  ...
# 28378                     2          223                         14.0  ...
# 28379                     2          588                          0.0  ...
# 28380                     3          274                          NaN  ...
# 28381                     2          474                         59.0  ...
#
# ...

# %%
df.shape
# Out:
# (28382, 21)

# %%
df.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code',
#        'days_since_last_transaction', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 28382

# %%
df.shape[1]
# Out:
# 21

# %%
df.iloc[5:9, 4:9]
# Out:
#    dependents     occupation    city  customer_nw_category  branch_code
# 5         0.0  self_employed  1096.0                     2         1666
# 6         0.0        retired  1020.0                     1            1
# 7         0.0  self_employed   623.0                     2          317
# 8         0.0       salaried  1096.0                     2         4110

# %%
df.iloc[:5]
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df[df['age']==1]
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 2642          2815      824    1     NaN         0.0  self_employed   834.0
# 13322        14225      217    1  Female         0.0        student  1020.0
# 19977        21317      842    1    Male         0.0  self_employed   105.0
# 24325        25956      193    1  Female         NaN        student  1096.0
#
#        customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 2642                      2         1224                         55.0  ...
# 13322                     3          159                         46.0  ...
# 19977                     2          650                         18.0  ...
# 24325                     1          503                         47.0  ...
#
#        previous_month_end_balance  average_monthly_balance_prevQ  \
# 2642                      4832.03                        4016.55
# 13322                     1767.86                        1578.98
# ...

# %%
df.sort_values('age')
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 19977        21317      842    1    Male         0.0  self_employed   105.0
# 24325        25956      193    1  Female         NaN        student  1096.0
# 13322        14225      217    1  Female         0.0        student  1020.0
# 2642          2815      824    1     NaN         0.0  self_employed   834.0
# 16611        17730      610    2    Male         NaN        student   318.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 25618        27352      573   90     NaN         NaN  self_employed    15.0
# 13695        14620     5901   90  Female         0.0  self_employed  1020.0
# 25624        27358     5527   90    Male         0.0  self_employed   427.0
# 4935          5252     3068   90    Male         0.0  self_employed   617.0
# 12272        13106     1614   90     NaN         NaN  self_employed  1271.0
#
# ...

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df.sort_values(by=['age', 'gender'])[:9]
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 13322        14225      217    1  Female         0.0        student  1020.0
# 24325        25956      193    1  Female         NaN        student  1096.0
# 19977        21317      842    1    Male         0.0  self_employed   105.0
# 2642          2815      824    1     NaN         0.0  self_employed   834.0
# 5214          5550      265    2  Female         NaN        student   621.0
# 5694          6068      642    2  Female         NaN        student   334.0
# 6188          6595      536    2  Female         0.0        student  1084.0
# 7472          7956      383    2  Female         NaN        student  1232.0
# 10754        11491      476    2  Female         NaN        student  1111.0
#
#        customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 13322                     3          159                         46.0  ...
# ...

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
a1=df.iloc[:5]
a2=df.iloc[6:8]
a3=df.iloc[9:11]

# %%
a=pd.concat([a1, a2, a3], keys=['a1', 'a2', 'a3'])

# %%
a1
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
a2
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 6            8     5922   72   Male         0.0        retired  1020.0
# 7            9     1145   46   Male         0.0  self_employed   623.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 6                     1            1                         98.0  ...
# 7                     2          317                        172.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 6                     7714.19                        7859.74
# 7                     8519.53                        6511.82
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 6                        11232.37                  0.64
# 7                        16314.17                  0.27
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 6                   0.64              1299.64                439.26
# ...

# %%
a3
# Out:
#     customer_id  vintage  age gender  dependents     occupation    city  \
# 9            11     3379   40   Male         3.0  self_employed  1020.0
# 10           12      661   68   Male         0.0        retired   409.0
#
#     customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 9                      2           38                          0.0  ...
# 10                     3          709                          5.0  ...
#
#     previous_month_end_balance  average_monthly_balance_prevQ  \
# 9                      4244.38                        2168.53
# 10                     1571.47                        1722.60
#
#     average_monthly_balance_prevQ2  current_month_credit  \
# 9                          1864.33               6912.29
# 10                          747.66                443.40
#
#     previous_month_credit  current_month_debit  previous_month_debit  \
# 9                 4206.13              1887.30               1348.85
# ...

# %%
a
# Out:
#        customer_id  vintage  age gender  dependents     occupation    city  \
# a1 0             1     3135   66   Male         0.0  self_employed   187.0
#    1             2      310   35   Male         0.0  self_employed     NaN
#    2             4     2356   31   Male         0.0       salaried   146.0
#    3             5      478   90    NaN         NaN  self_employed  1020.0
#    4             6     2531   42   Male         2.0  self_employed  1494.0
# a2 6             8     5922   72   Male         0.0        retired  1020.0
#    7             9     1145   46   Male         0.0  self_employed   623.0
# a3 9            11     3379   40   Male         3.0  self_employed  1020.0
#    10           12      661   68   Male         0.0        retired   409.0
#
#        customer_nw_category  branch_code  days_since_last_transaction  ...  \
# a1 0                      2          755                        224.0  ...
# ...

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
b1=df[['customer_id', 'age', 'gender']].head(6)

# %%
b2=df[['customer_id', 'city', 'vintage']].iloc[4:8]

# %%
pd.concat([b1, b2], axis=1, join='inner')
# Out:
#    customer_id  age  gender  customer_id    city  vintage
# 4            6   42    Male            6  1494.0     2531
# 5            7   42  Female            7  1096.0      263

# %%
pd.concat([b1, b2], axis=1)
# Out:
#    customer_id   age  gender  customer_id    city  vintage
# 0          1.0  66.0    Male          NaN     NaN      NaN
# 1          2.0  35.0    Male          NaN     NaN      NaN
# 2          4.0  31.0    Male          NaN     NaN      NaN
# 3          5.0  90.0     NaN          NaN     NaN      NaN
# 4          6.0  42.0    Male          6.0  1494.0   2531.0
# 5          7.0  42.0  Female          7.0  1096.0    263.0
# 6          NaN   NaN     NaN          8.0  1020.0   5922.0
# 7          NaN   NaN     NaN          9.0   623.0   1145.0

# %%
c1={'name':['Alex', 'adolf', 'bieden', 'Bravo'], 'roll_no':[1, 2, 3, 4]}
s1={'hindi':[25, 28, 24], 'english':[23, 26, 29], 'roll_no':[1, 2, 3]}

# %%
c2=pd.DataFrame(c1)

# %%
s2=pd.DataFrame(s1)

# %%
c2
# Out:
#      name  roll_no
# 0    Alex        1
# 1   adolf        2
# 2  bieden        3
# 3   Bravo        4

# %%
s2
# Out:
#    hindi  english  roll_no
# 0     25       23        1
# 1     28       26        2
# 2     24       29        3

# %%
pd.concat([c2, s2], axis=1)
# Out:
#      name  roll_no  hindi  english  roll_no
# 0    Alex        1   25.0     23.0      1.0
# 1   adolf        2   28.0     26.0      2.0
# 2  bieden        3   24.0     29.0      3.0
# 3   Bravo        4    NaN      NaN      NaN

# %%
pd.concat([c2, s2], axis=1, join='inner')
# Out:
#      name  roll_no  hindi  english  roll_no
# 0    Alex        1     25       23        1
# 1   adolf        2     28       26        2
# 2  bieden        3     24       29        3

# %%
pd.merge(c2, s2, on='roll_no')
# Out:
#      name  roll_no  hindi  english
# 0    Alex        1     25       23
# 1   adolf        2     28       26
# 2  bieden        3     24       29

# %%
pd.merge(c2, s2, on='roll_no', how='inner')
# Out:
#      name  roll_no  hindi  english
# 0    Alex        1     25       23
# 1   adolf        2     28       26
# 2  bieden        3     24       29

# %%
df.apply(lambda x:x[5])
# Out:
# customer_id                                   7
# vintage                                     263
# age                                          42
# gender                                   Female
# dependents                                    0
# occupation                        self_employed
# city                                       1096
# customer_nw_category                          2
# branch_code                                1666
# days_since_last_transaction                  60
# current_balance                         15202.2
# previous_month_end_balance              16059.3
# average_monthly_balance_prevQ           15211.3
# average_monthly_balance_prevQ2          13798.8
# current_month_credit                       0.36
# previous_month_credit                      0.36
# current_month_debit                       857.5
# previous_month_debit                     286.07
# current_month_balance                   15719.4
# previous_month_balance                  15349.8
# ...

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df.apply(lambda x:x['age'], axis=1)
#column access using apply function on dataframe
# Out:
# 0        66
# 1        35
# 2        31
# 3        90
# 4        42
#          ..
# 28377    10
# 28378    34
# 28379    47
# 28380    50
# 28381    18
# Length: 28382, dtype: int64

# %%
def change(x):
    if x>50:
        x=x*0
    return x

df['age'].apply(lambda x:change(x))[:6]
# Out:
# 0     0
# 1    35
# 2    31
# 3     0
# 4    42
# 5    42
# Name: age, dtype: int64

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...

# %%
df.groupby('age').first()
# Out:
#      customer_id  vintage  gender  dependents     occupation    city  \
# age
# 1           2815      824  Female         0.0  self_employed   834.0
# 2           1712      521    Male         0.0        student  1020.0
# 3            141      615  Female         0.0        student  1232.0
# 4             50      937    Male         0.0        student   318.0
# 5           1318      779  Female         0.0        student   656.0
# ..           ...      ...     ...         ...            ...     ...
# 86           449     5280    Male         1.0        retired  1020.0
# 87          1598     3088  Female         0.0  self_employed  1020.0
# 88           829     5542  Female         0.0        retired   623.0
# 89          1189     1803    Male         0.0        retired   334.0
# 90             5      478  Female         0.0  self_employed  1020.0
#
#      customer_nw_category  branch_code  days_since_last_transaction  \
# age
# ...

# %%
df.describe()
# Out:
#         customer_id       vintage           age    dependents          city  \
# count  28382.000000  28382.000000  28382.000000  25919.000000  27579.000000
# mean   15143.508667   2364.336446     48.208336      0.347236    796.109576
# std     8746.454456   1610.124506     17.807163      0.997661    432.872102
# min        1.000000    180.000000      1.000000      0.000000      0.000000
# 25%     7557.250000   1121.000000     36.000000      0.000000    409.000000
# 50%    15150.500000   2018.000000     46.000000      0.000000    834.000000
# 75%    22706.750000   3176.000000     60.000000      0.000000   1096.000000
# max    30301.000000  12899.000000     90.000000     52.000000   1649.000000
#
#        customer_nw_category   branch_code  days_since_last_transaction  \
# count          28382.000000  28382.000000                 25159.000000
# mean               2.225530    925.975019                    69.997814
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28382 entries, 0 to 28381
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     28382 non-null  int64
#  1   vintage                         28382 non-null  int64
#  2   age                             28382 non-null  int64
#  3   gender                          27857 non-null  object
#  4   dependents                      25919 non-null  float64
#  5   occupation                      28302 non-null  object
#  6   city                            27579 non-null  float64
#  7   customer_nw_category            28382 non-null  int64
#  8   branch_code                     28382 non-null  int64
#  9   days_since_last_transaction     25159 non-null  float64
#  10  current_balance                 28382 non-null  float64
#  11  previous_month_end_balance      28382 non-null  float64
# ...

# %%
df.groupby(['occupation', 'gender']).first()
# Out:
#                       customer_id  vintage  age  dependents    city  \
# occupation    gender
# company       Female         6956     5344   36         0.0   649.0
#               Male           1057     5451   90         0.0  1096.0
# retired       Female           34     2963   64         0.0  1020.0
#               Male              8     5922   72         0.0  1020.0
# salaried      Female           32     2204   33         0.0   834.0
#               Male              4     2356   31         0.0   146.0
# self_employed Female            7      263   42         0.0  1096.0
#               Male              1     3135   66         0.0   187.0
# student       Female           47     2255   17         0.0   630.0
#               Male             37     2671    9         0.0   623.0
#
#                       customer_nw_category  branch_code  \
# occupation    gender
# company       Female                     2         3636
#               Male                       1           11
# ...

# %%
pd.crosstab(df['occupation'], df['gender'], margins=True)
# Out:
# gender         Female   Male    All
# occupation
# company             6     28     34
# retired           389   1634   2023
# salaried         1838   4864   6702
# self_employed    8053   8911  16964
# student          1006   1052   2058
# All             11292  16489  27781

# %%
pd.pivot_table(df, index=['gender'], values='age')
# Out:
#               age
# gender
# Female  46.249536
# Male    48.239425

# %%
pd.pivot_table(df, index=['occupation', 'gender'], values='age')
# Out:
#                             age
# occupation    gender
# company       Female  46.500000
#               Male    70.500000
# retired       Female  71.385604
#               Male    72.350061
# salaried      Female  41.584875
#               Male    45.009046
# self_employed Female  49.421582
#               Male    48.849736
# student       Female  19.508946
#               Male    19.312738

# %%
df.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# ...
